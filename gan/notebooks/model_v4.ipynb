# %% [markdown]
# # Model v4
# Anthony Lee 2025-01-03
#
# Improvement TODO:
# - Fixed loss function

# %%
from gan.gan import CycleGAN, train_one_epoch, checkpoint_save
from gan.data import ImageDataset, ImageDataLoader
import torch
from pprint import pprint
from gan.plotting_utility import plot_before_after
from gan.data_processing import map_tanh_to_rgb

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print( torch.cuda.get_device_properties(device) )


monet_dataset = ImageDataset(data_dir="../data/gan-getting-started/monet_jpg")
photo_dataset = ImageDataset(data_dir="../data/gan-getting-started/photo_jpg")

monet_dataloader = ImageDataLoader(monet_dataset)
photo_dataloader = ImageDataLoader(photo_dataset)
# Out:
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 3070', major=8, minor=6, total_memory=8191MB, multi_processor_count=46, uuid=0e2d35a6-9344-fc39-0a99-bd4343293f22, L2_cache_size=4MB)

# %%
model = CycleGAN()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-4, betas=(0.5, 0.999))
epoch_count = 50
for idx_epoch in range(epoch_count):

    loss_tracker = train_one_epoch(monet_dataloader=monet_dataloader, 
                    photo_dataloader=photo_dataloader,
                    optimizer=optimizer,
                    model=model, 
                    device=device)
    
    ## Plot an example image
    idx = 20

    # Photo to monet
    input = photo_dataset[idx].to(device=device)
    output = model.generate_monet(input)  # Need to move to CPU?
    output = map_tanh_to_rgb(output)
    fig1 = plot_before_after(input, output, suptitle=f"Epoch {idx_epoch}: Photo -> Monet")
    # fig1.show()

    # Monet to photo
    input = monet_dataset[idx].to(device=device)
    output = model.generate_photo(input) # Need to move to CPU?
    output = map_tanh_to_rgb(output)
    fig2 = plot_before_after(input, output, suptitle=f"Epoch {idx_epoch}: Monet -> Photo")
    # fig2.show()

    ## Checkpoint
    if idx_epoch % 5 == 0:
        fig1.savefig(f"./epoch_{idx_epoch}_fake_monet.jpg")
        fig2.savefig(f"./epoch_{idx_epoch}_fake_photo.jpg")
        _ = checkpoint_save(epoch=idx_epoch, 
                    save_path=".", 
                    model=model,
                    optimizer=optimizer,
                    loss_tracker=loss_tracker)
# Out:
# Training...: 0batch [00:00, ?batch/s]/home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [110,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [115,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [118,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [1,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [18,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [25,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [8,0,0], thread: [31,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [14,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [15,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [22,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [24,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [70,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [72,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [73,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [74,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [75,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [85,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [90,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [91,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [4,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [15,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [31,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [72,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [73,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [76,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [79,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [16,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [4,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [25,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [27,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [31,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [65,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [76,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [85,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [91,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [32,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [38,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [45,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [49,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [51,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [52,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [54,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [62,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [103,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [104,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [105,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [106,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [114,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [17,0,0], thread: [124,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [64,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [70,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [72,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [74,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [75,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [80,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [81,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [84,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [1,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [99,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [104,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [105,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [106,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [108,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [115,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [12,0,0], thread: [124,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [99,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [108,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [118,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [5,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [64,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [65,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [66,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [73,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [77,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [84,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [90,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [0,0,0], thread: [91,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [113,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [119,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [124,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [8,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [22,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [2,0,0], thread: [29,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [99,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [115,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [32,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [35,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [42,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [50,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [52,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [62,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [15,0,0], thread: [63,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [3,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [8,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [25,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [9,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [11,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [11,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [11,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [11,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [11,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [11,0,0], thread: [104,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [11,0,0], thread: [106,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ...
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [124,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [13,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [33,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [34,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [35,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [38,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [40,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [41,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [42,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [45,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [46,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [47,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [48,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [49,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [50,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [54,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [56,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [59,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [60,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [14,0,0], thread: [61,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [33,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [34,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [35,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [38,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [40,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [42,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [45,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [46,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [47,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [48,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [49,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [51,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [52,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [55,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [56,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [57,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [58,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [59,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [61,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [62,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# /home/conda/feedstock_root/build_artifacts/libtorch_1733624414920/work/aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [10,0,0], thread: [63,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# Training...: 0batch [00:00, ?batch/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 6
#       3 epoch_count = 50
#       4 for idx_epoch in range(epoch_count):
# ----> 6     loss_tracker = train_one_epoch(monet_dataloader=monet_dataloader,
#       7                     photo_dataloader=photo_dataloader,
#       8                     optimizer=optimizer,
#       9                     model=model,
#      10                     device=device)
#      12     ## Plot an example image
#      13     idx = 20
#
# File ~/github/kaggle_kernels/gan/src/gan/gan.py:166, in train_one_epoch(monet_dataloader, photo_dataloader, model, optimizer, device)
#     160 # Train the model one batch at a time
#     161 for idx_batch, (real_monet_batch, real_photo_batch) in tqdm(enumerate(zip(monet_dataloader, photo_dataloader)), desc="Training...", unit="batch"):
#     162
#     163     # print(f"Training {idx_batch}-th batch...")
#     164
#     165     # Forward pass and get loss dict
# --> 166     loss_dict = train_one_batch(
#     167         real_monet_batch=real_monet_batch,
#     168         real_photo_batch=real_photo_batch,
#     169         model = model,
#     170         optimizer = optimizer,
#     171         device=device)
#     173     # Update loss tracker - Make sure to not accumulate history
#     174     # https://pytorch.org/docs/stable/notes/faq.html
#     175     for key in loss_dict:
#
# File ~/github/kaggle_kernels/gan/src/gan/gan.py:200, in train_one_batch(real_monet_batch, real_photo_batch, model, optimizer, device)
#     197 real_photo_batch = normalize_image(real_photo_batch).to(device=device)
#     199 # Forward pass to get the loss
# --> 200 loss_dict = model(real_monet_batch, real_photo_batch)
#     201 combined_loss = torch.zeros((),device=device)
#     202 for loss_name, loss_value in loss_dict.items():
#
# File ~/miniconda3/envs/torch_cuda/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_cuda/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/github/kaggle_kernels/gan/src/gan/gan.py:73, in CycleGAN.forward(self, real_monet, real_photo)
#      70 photo_gen_loss = GeneratorLoss()(disc_fake_photo)  # Compares against a matrix of ones
#      72 # Evaluate loss - discriminator
# ---> 73 monet_dis_loss = DiscriminatorLoss()(real=disc_real_monet, generated=disc_fake_monet)
#      74 photo_dis_loss = DiscriminatorLoss()(real=disc_real_photo, generated=disc_fake_photo)
#      76 # Total generator loss
#
# File ~/miniconda3/envs/torch_cuda/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_cuda/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/github/kaggle_kernels/gan/src/gan/loss.py:18, in DiscriminatorLoss.forward(self, real, generated)
#      16 real_loss = nn.BCELoss(reduction="mean")(input=real, target=torch.ones_like(real))
#      17 generated_loss = nn.BCELoss(reduction="mean")(input=generated, target=torch.zeros_like(generated))
# ---> 18 avg_discriminator_loss = (real_loss + generated_loss) / 2
#      20 return avg_discriminator_loss
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
