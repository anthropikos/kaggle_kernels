# %%
from pdf2image import convert_from_path
import matplotlib.pyplot as plt
from pathlib import Path

for i in Path().cwd().glob("**/*.pdf"):
    image = convert_from_path(i)[0]
    plt.imshow(image)
    plt.axis("off")
    plt.show()
